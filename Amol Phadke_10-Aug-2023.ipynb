# %% [markdown]
# Context
#
# I have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Here, we are analysing different aspects of E-Commerce Company by doing Exploratory Data Analysis.

# %% [markdown]
# Load all the required Packages for which would be used in doing the data Analysis

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# Load the data into pandas dataframe and view the details

# %%
df_comp = pd.read_csv("D:\Amol\Great Learning Class\Projects\PDS Project\E-Commerce.csv")

# %% [markdown]
# Checking if the data frame is loaded or not by using head and tail functions

# %%
df_comp.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %%
df_comp.tail()
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8901             04-12-2020     04-12-2020
# 8902             04-12-2020     04-12-2020
# 8903             04-12-2020     04-12-2020
# 8904             04-12-2020     04-12-2020
# 8905             04-12-2020     04-12-2020
#
#                                            product_name product_main_category  \
# 8901  Sinina Chanderi Embroidered Salwar Suit Dupatt...             Clothing
# 8902  Aarushi Fashion Chanderi Embroidered Salwar Su...             Clothing
# 8903  Ambika Lahenga Embroidered Lehenga, Choli and ...             Clothing
# ...

# %% [markdown]
# Let's now understand the shape of data
# We will use the shape function to get these details

# %%
df_comp.shape
# Out:
# (8906, 17)

# %% [markdown]
# As we see in above output we have 8906 Rows and 17 Columns . Let's print them with following command

# %%
print("The number of rows in the data set are:",df_comp.shape[0],"\n And number of columns in data set are:",df_comp.shape[1])
# Out:
# The number of rows in the data set are: 8906
#  And number of columns in data set are: 17

# %% [markdown]
# Data type informations
# Now let's get all the data types information by using the info function

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# Observations:
#
# We have 14 fields with 'object' datatype, 1 field of datatype 'float' and 2 fields with 'integer' datatype
#
# Check the missing values in the data
#
# By looking at the data I dont see any null values and this data seems to be clean data

# %% [markdown]
# Null Values and Missing values:
# We will use isnull and isna functions to find out is they values are Null or missing in the data set. 'sum()' method followed by 'isnull()' adds up all the True instances per column to give a summary of missing values per column

# %%
df_comp.isnull().sum().sort_values(ascending=False)
# Out:
# Customer_uniq_id              0
# product_category_subfilter    0
# product_specifications        0
# Brand                         0
# product_rating                0
# discounted_price              0
# retail_price                  0
# product_unique ID             0
# product_category_filter       0
# Region                        0
# product_subcategory           0
# product_main_category         0
# product_name                  0
# Delivered_Date                0
# Expected_Delivery_Date        0
# Order_Date                    0
# description                   0
# dtype: int64

# %% [markdown]
# As you see All the values are shown as 0 here which means we dont have null values.
# Now let's check if anything we have NA values

# %%
df_comp.isna().sum().sort_values(ascending=False)
# Out:
# Customer_uniq_id              0
# product_category_subfilter    0
# product_specifications        0
# Brand                         0
# product_rating                0
# discounted_price              0
# retail_price                  0
# product_unique ID             0
# product_category_filter       0
# Region                        0
# product_subcategory           0
# product_main_category         0
# product_name                  0
# Delivered_Date                0
# Expected_Delivery_Date        0
# Order_Date                    0
# description                   0
# dtype: int64

# %% [markdown]
# We dont have any NA values as well which suggests we have a clean data

# %% [markdown]
# Data Analysis
# 'describe()' method generates descriptive statistics.

# %%
df_comp.describe(include='all').T
# Out:
#                              count unique  \
# Customer_uniq_id              8906   8906
# Region                        8906      4
# Order_Date                    8906    127
# Expected_Delivery_Date        8906    135
# Delivered_Date                8906    144
# product_name                  8906   5959
# product_main_category         8906     26
# product_subcategory           8906    135
# product_category_filter       8906    498
# product_category_subfilter    8906   1840
# product_unique ID             8906   8904
# retail_price                8906.0    NaN
# discounted_price            8906.0    NaN
# product_rating              8906.0    NaN
# Brand                         8906   2484
# product_specifications        8906   8446
# description                   8906   7962
#
#                                                                           top  \
# Customer_uniq_id                             e71017e224688489edfe856f2308806d
# ...

# %% [markdown]
# Q 1. To get familiar with the data

# %% [markdown]
# a) Print out the first 10 and the last 10 records of the data

# %%
#1st 10 records of the data frame are as follows:

df_comp.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
# Last 10 records of the data frame are as follows:

df_comp.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
#  b) How many rows and columns are present in the dataset? Use any two different methods to extract this information

# %%
#1st method using shape function
df_comp.shape
# Out:
# (8906, 17)

# %%
# Method is as follows again using Shape function with Print Statement

print("The number of rows in the data set are:",df_comp.shape[0],"\n And number of columns in data set are:",df_comp.shape[1])
# Out:
# The number of rows in the data set are: 8906
#  And number of columns in data set are: 17

# %% [markdown]
# 2nd method is using the info function we can get rows and columns information
#
# here also we see the Rows and columns

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# c) How many object data types are there

# %%
# As you see above in info function we can see there arre 14 object Data types are there
# Follwing is another way to find the number of object data types in Dataframe

print("The number of object Datatypes in the data frame are:",(df_comp.dtypes == 'object').sum())
# Out:
# The number of object Datatypes in the data frame are: 14

# %% [markdown]
# d) Is there any Boolean data type

# %% [markdown]
# We dont have any boolean data types in the Data frame

# %% [markdown]
# Q 2. Eliminating the non-informative columns.

# %%
a) Drop the columns product_specifications and description.

# %%
df_comp.drop(['product_specifications','description'], axis=1, inplace=True)

# %%
# Check the rows and columns again
df_comp.shape
# Out:
# (8906, 15)

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# As you see now the product_specifications and description columns are dropped and they dont exists in Dataframe

# %% [markdown]
# b) Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly

# %%
#df_comp.drop(['product_specifications','description'], axis=1, inplace=True)

# %% [markdown]
# In the above code you see the method "inplace=True" is used to permanently delete the columns in Data Frame and Axis = 1 is meant for columns

# %%
Q 3. Here we summarize the data at Brand level.

# %%
# 2484 are the unique number of Brands in the data set
df_comp.Brand.nunique()
# Out:
# 2484

# %% [markdown]
# Above nunique function is used to get the unique numbers of brand that are available in the data set and just unique function will name the brands

# %% [markdown]
# b) Note that each Brand contains multiple products. Show the average product_rating within each Brand

# %%
round(df_comp.groupby('Brand')['product_rating'].mean(),2).sort_values(ascending = False)
# Out:
# Brand
#  TARKAN                   5.0
# INDIANO                   5.0
# PUMPKIN PATCH             5.0
# PURE SOURCE               5.0
# BRAHAAN BLUE TAG          5.0
#                          ...
# BRIGHT HOME APPLIANCES    1.0
# TWIN TWINE                1.0
# BRECKEN PAUL              1.0
# QUENELL                   1.0
# FIRANGI                   1.0
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# Above code shows that we have to group by Brand and then display the average Product ratings in the brand by using mean function and have used 2 to restrict the decimals to 2 place. Once we have displayed the ratings I am sorting them in descending order

# %% [markdown]
# Q 4. Next we study the main categories of the products.¶

# %% [markdown]
# a) Create an appropriate plot to show the count of items ordered for each product_main_category

# %%
df_comp.product_main_category.nunique()
# Out:
# 26

# %%
plt.figure(figsize=(13,7))
sns.countplot(data=df_comp,x='product_main_category',order = df_comp['product_main_category'].value_counts().index);
plt.xticks(rotation=90)
plt.title("Product Main Category Items Ordered")
plt.show()

# %% [markdown]
# Above Bar Chart shows the count of items ordered for each of Product Main Category and they are sorted by descenting order as well.

# %% [markdown]
# b) From the plot identify for which two product_main_category(s) maximum and minimum orders were placed

# %% [markdown]
# From the Chart above its clear that Maximum orders were placed for "Clothing" Product Main Category and Minimum orders were placed for "Wearable Smart devices".

# %%
c) Write code to print out the top 5 product_main_category(s) in descending order?

# %%
df_comp.groupby(by='product_main_category').product_name.nunique().sort_values(ascending = False).head(5)
# Out:
# product_main_category
# Clothing                       1522
# Automotive                      975
# Computers                       551
# Home Decor & Festive Needs      544
# Mobiles & Accessories           462
# Name: product_name, dtype: int64

# %% [markdown]
# Above Code is for the showing the Top 5 Product Main Category which is grouped by and then used Product Name as a unique key to get the count of product in each category. Sorted them in Descending order

# %% [markdown]
# In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business. The E-Commerce company has the following rule for computing their own revenue:
#
# The company charges
# (i) 25% on the orders having final price (discounted price) greater than 600
# (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
# (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
# (iv) Otherwise, 5% on the final price (discounted price) </font>

# %%
df_comp_revenue = df_comp.copy()

# %%
def calculate_revenue(discounted_price):
    if (discounted_price > 600):
        return 0.25 * discounted_price
    elif ((discounted_price > 350) and (discounted_price <= 600)):
        return 0.15 * discounted_price
    elif ((discounted_price > 100) and (discounted_price <= 350)):
        return 0.10 * discounted_price
    else:
        return 0.05 * discounted_price
    
    
        
    
df_comp_revenue['Revenue'] = df_comp_revenue['discounted_price'].apply(calculate_revenue)

# %%
df_comp_revenue.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %%
print("Total Revenue generated by the E-Commerce company over all orders placed:",df_comp_revenue['Revenue'].sum())
# Out:
# Total Revenue generated by the E-Commerce company over all orders placed: 2217486.85

# %% [markdown]
# Ans 5: Did the following things to come to solution for question 5:
# 1. Copied the orginal data set into new data frame called as df_comp_revenue to make sure I dont mess the original data set
# 2. Then created a function called as "Calculate_revenue" and used the conditional statements to add get the correct revenue information for every order
# 3. Then inserted a new column into Dataset called as "Revenue" and applied the function "Calculate_revenue" this made sure that we have added Revenue for every order value based on the conditions provided
# 4. Last thing I did is that called a Sum function to Revenue column to get the total revenue of a company

# %% [markdown]
# Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order

# %%
df_brand_revenue=df_comp_revenue.copy()

# %%
df_comp_revenue.shape
# Out:
# (8906, 16)

# %%
df_comp_revenue['Brand_Revenue'] = df_comp_revenue['discounted_price'] - df_comp_revenue['Revenue']

# %%
df_comp_revenue.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %%
print("Total Brand Revenue is:",df_comp_revenue['Brand_Revenue'].sum())
# Out:
# Total Brand Revenue is: 7522992.15

# %% [markdown]
# Added a new column in the Data Frame called as"Brand_Revenue" and also did the computation for this value
#
# Above value is printed to get the TOtal Brand Revenue

# %%
#the top 10 Brand having maximum revenue in descending order

df_comp_revenue.groupby('Brand')['Brand_Revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# Brand
# ALLURE AUTO     498464.25
# GAGA            237390.00
# SLIM            212062.60
# DAILYOBJECTS    181980.00
# DIVINITI        143115.00
# THELOSTPUPPY    127287.50
# REGULAR         126536.50
# ENTHOPIA        123146.25
# ASUS             99241.50
# SPRINGWEL        88978.50
# Name: Brand_Revenue, dtype: float64

# %% [markdown]
# In order to get the Top 10 brands with Highest Revenue I have used the group by function for Brand and did the sum of Brand Revenue this helped us get all the Brands revenue group. Sorted them in decending order and applied head function to get the Top 10 brands

# %%
df_comp_revenue.product_main_category.nunique()
# Out:
# 26

# %% [markdown]
# Q 7. Compare prices for each product.

# %% [markdown]
# a) Draw boxplots of retail_price & discounted_price

# %%
# Box plot for discounted priceses
plt.figure(figsize=(15,7))
sns.boxplot(data=df_comp_revenue,x='product_main_category',y='discounted_price');
plt.xticks(rotation=90)
plt.title("Box Plot for Discounted Prices")
plt.show()

# %%
# Box plot for retail price
plt.figure(figsize=(15,7))
sns.boxplot(data=df_comp_revenue,x='product_main_category',y='retail_price');
plt.xticks(rotation=90)
plt.title("Box Plot for Retails Prices")
plt.show()

# %% [markdown]
# 7 b) Are there any outliers?

# %% [markdown]
# Yes there are outliers for both retail prices as well as for discounted prices

# %% [markdown]
# 7 c) Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis)

# %%
sns.scatterplot(data=df_comp,x='retail_price',y='discounted_price');
plt.title("Scatter Plot for Retial Price and Discounter Price")
plt.show()

# %%
df_comp.head()
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %% [markdown]
# Q 8. Create a new dataframe to include the Brand specific information as stated

# %% [markdown]
# i. total number of orders placed per Brand
#
# Created a new data frame called df_brand_info and then added a column for Orders Place and no of orders I have calculated by using group by functino for Brand and then using size() function agaisnt Product Unique ID I could have used this againts other column as well

# %%
df_brand_info = pd.DataFrame()

df_brand_info['Orders Place'] = df_comp.groupby('Brand')['product_unique ID'].size()

# %%
df_brand_info
# Out:
#              Orders Place
# Brand
# 1OAK                    2
# 3A AUTOCARE            41
# 3D MAT                  1
# 3KFACTORY               1
# 4D                      5
# ...                   ...
# ZORDEN                  1
# ZOSIGN                  5
# ZRESTHA                 1
# ZYXEL                   9
#  TARKAN                 1
#
# [2484 rows x 1 columns]

# %%
# FOllowing shows we have total order as 8906 which is actually the rows in Data frame
df_brand_info['Orders Place'].sum()
# Out:
# 8906

# %% [markdown]
# ii. total retail_price per Brand

# %%
df_brand_info['Total Retail Price'] = df_comp.groupby('Brand')['retail_price'].sum()

# %%
df_brand_info
# Out:
#              Orders Place  Total Discounted Price  Total Retail Price
# Brand
# 1OAK                    2                    1274                1698
# 3A AUTOCARE            41                   74134              107059
# 3D MAT                  1                    6999                7250
# 3KFACTORY               1                     174                 399
# 4D                      5                    7948               17500
# ...                   ...                     ...                 ...
# ZORDEN                  1                    2799                3999
# ZOSIGN                  5                    6995                6995
# ZRESTHA                 1                     899                1999
# ZYXEL                   9                   35392               64742
#  TARKAN                 1                     349                1999
#
# [2484 rows x 3 columns]

# %%
df_brand_info.drop(['Total Discounted Price'],axis=1,inplace=True)

# %%
df_brand_info
# Out:
#              Orders Place  Total Retail Price
# Brand
# 1OAK                    2                1698
# 3A AUTOCARE            41              107059
# 3D MAT                  1                7250
# 3KFACTORY               1                 399
# 4D                      5               17500
# ...                   ...                 ...
# ZORDEN                  1                3999
# ZOSIGN                  5                6995
# ZRESTHA                 1                1999
# ZYXEL                   9               64742
#  TARKAN                 1                1999
#
# [2484 rows x 2 columns]

# %% [markdown]
# To get the Retail price per brand again used the group by function against each Brand and added sum function on retail_price column

# %%
df_brand_info['Total Discounted Price'] = df_comp.groupby('Brand')['discounted_price'].sum()
df_brand_info
# Out:
#              Orders Place  Total Retail Price  Total Discounted Price
# Brand
# 1OAK                    2                1698                    1274
# 3A AUTOCARE            41              107059                   74134
# 3D MAT                  1                7250                    6999
# 3KFACTORY               1                 399                     174
# 4D                      5               17500                    7948
# ...                   ...                 ...                     ...
# ZORDEN                  1                3999                    2799
# ZOSIGN                  5                6995                    6995
# ZRESTHA                 1                1999                     899
# ZYXEL                   9               64742                   35392
#  TARKAN                 1                1999                     349
#
# [2484 rows x 3 columns]

# %% [markdown]
# iv. total BrandRevenue generated per Brand

# %%
df_brand_info['Total Brand Revenue'] = df_comp_revenue.groupby('Brand')['Brand_Revenue'].sum()
df_brand_info
# Out:
#              Orders Place  Total Retail Price  Total Discounted Price  \
# Brand
# 1OAK                    2                1698                    1274
# 3A AUTOCARE            41              107059                   74134
# 3D MAT                  1                7250                    6999
# 3KFACTORY               1                 399                     174
# 4D                      5               17500                    7948
# ...                   ...                 ...                     ...
# ZORDEN                  1                3999                    2799
# ZOSIGN                  5                6995                    6995
# ZRESTHA                 1                1999                     899
# ZYXEL                   9               64742                   35392
#  TARKAN                 1                1999                     349
#
#              Total Brand Revenue
# Brand
# 1OAK                     1015.40
# 3A AUTOCARE             55647.90
# ...

# %% [markdown]
# Following is a  pairplot using these four features

# %%
sns.pairplot(data=df_brand_info[['Orders Place','Total Retail Price','Total Discounted Price','Total Brand Revenue']]);

# %% [markdown]
# Q 9.Compare performance regionwise

# %% [markdown]
# a) Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately

# %%
df_comp_revenue.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
df_comp_revenue['Order_Date'] = pd.to_datetime(df_comp_revenue['Order_Date'],format='%d-%m-%Y')

# %%
df_comp_revenue['Month'] = df_comp_revenue['Order_Date'].dt.to_period('m')

# %%
df_comp_revenue['year'] = df_comp_revenue['Order_Date'].dt.year
df_comp_revenue['months'] = df_comp_revenue['Order_Date'].dt.month

# %%
import calendar
df_comp_revenue['month_name'] = df_comp_revenue['months'].apply(lambda x: calendar.month_name[x])

# %%
df_comp_revenue.head()
# Out:
#                    Customer_uniq_id Region Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East  2021-10-24             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East  2021-10-24             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West 2021-10-24             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West 2021-10-24             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East  2021-09-03             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %% [markdown]
# Here I have used some date to time function to conver the given Order Date format into Year and Month. Once I got this information I have segreggated these into Year nd Month by dt.Year and dt.month func respectively. Once I had this information only thing which was pending was to conver the numeric into Text Format for which I have used calendar libray and used Lamdba fuction

# %%
df_comp_revenue.info()
#sns.lineplot(data=df_comp_revenue, x='year', y='Revenue');
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   datetime64[ns]
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %%
df_comp_revenue_new1 = df_comp_revenue.copy()

# %%
df_comp_revenue_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   datetime64[ns]
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %%
df_comp_revenue_new1['Month'] = df_comp_revenue_new1['Month'].astype(str)

df_comp_revenue_new1['Revenue'] = df_comp_revenue_new1['Revenue'].astype(int)

# %%
df_comp_revenue_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   datetime64[ns]
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %%
df_comp_revenue_new1.head()
# Out:
#                    Customer_uniq_id Region Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East  2021-10-24             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East  2021-10-24             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West 2021-10-24             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West 2021-10-24             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East  2021-09-03             04-09-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 3     25-10-2021  Tiara Diaries 2016-2017 Designer LA Kaarta "TA...
# 4     04-09-2021                KAJCI Embroidered Women's Waistcoat
#
#   product_main_category    product_subcategory product_category_filter  \
# ...

# %%
sns.lineplot(data=df_comp_revenue, x='year', y='Revenue');

# %%
#pd.crosstab(index= mydata['post_transform'],columns=mydata['Dismissal'],
  #          values= mydata['RunsScored'],margins=True,aggfunc='mean')

ct=pd.crosstab(index=df_comp_revenue['Month'],columns=df_comp_revenue['Region'],
               values=df_comp_revenue['Revenue'],margins=True,aggfunc='sum')
                      

#ct=pd.crosstab(mydata['Opposition'],mydata['Dismissal'], margins=True)
#   values= df_comp_revenue['RunsScored'],margins=True,aggfunc='mean')

ct.drop('All',inplace=True)
ct.drop('All',axis=1,inplace=True)
#ct.plot.bar(figsize=(10,6))


#plt.figure(figsize=(15,7))
#sns.lineplot(data=ct,margins=True)
#plt.ylabel("Avg Runs Scored")
#plt.show()

# %%
ct
# Out:
# Region       East       North     South       West
# Month
# 2020-12  363413.85  195149.95  95088.25  302971.95
# 2021-01  218740.60   96015.10  52815.80  145593.75
# 2021-02   14347.25    7137.35   4670.85   15020.90
# 2021-03  124934.10   40733.95  61932.15  119632.50
# 2021-04   56293.05   29758.35  18550.10   46845.20
# 2021-05   24230.50   13106.50   3708.75   18631.85
# 2021-06   54231.60   29552.35  19550.75   40579.80
# 2021-07     351.35     306.00       NaN     537.00
# 2021-08     824.75     374.75       NaN     736.75
# 2021-09     680.15        NaN       NaN        NaN
# 2021-10     202.25        NaN       NaN     236.75

# %%
plt.figure(figsize=(12,6))
ct.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Revenue')
#plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 9.a Above is the line char for each Region Month wise

# %%
9.b
Identify the best and the worst performing months for each region

East Region - Best Performing Month is December 2010 and worst performing is October 2021
North Region - Best Performing Month is Decemebr 2020 and worst performing is August 2021
South Region - Best Performing month is December 2020 and worst performing is May 2021
West Region - Best Performing month is December 2020 and worst performing is Otober 2021

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell'
